# %% [markdown]
# # Analiza i Bazy Danych

# %% [markdown]
# ***Notatki***
#     df.to_csv("dem_score.csv")
#     df.loc[id==[mx000]] # tak sie odwolujemy do df
#     wieksze np. od jakiejs temperatury, nizej operacja na ciagow bitow &
#     df.loc[(id=='') & (d1>10)]
#
# 10 minutes to pandas sobie obczaic
#      pd.read_excel('dem_score.xlsx', index_col=0)

# %%
import pandas as pd
# df - data frame

df = pd.read_csv("Datasets/tb.csv")

df
# Out:
#      iso2  year   new_sp  new_sp_m04  new_sp_m514  new_sp_m014  new_sp_m1524  \
# 0      AD  1989      NaN         NaN          NaN          NaN           NaN
# 1      AD  1990      NaN         NaN          NaN          NaN           NaN
# 2      AD  1991      NaN         NaN          NaN          NaN           NaN
# 3      AD  1992      NaN         NaN          NaN          NaN           NaN
# 4      AD  1993     15.0         NaN          NaN          NaN           NaN
# ...   ...   ...      ...         ...          ...          ...           ...
# 5764   ZW  2004  14581.0         NaN          NaN        187.0         833.0
# 5765   ZW  2005  13155.0         NaN          NaN        210.0         837.0
# 5766   ZW  2006  12718.0         NaN          NaN        215.0         736.0
# 5767   ZW  2007  10583.0         6.0        132.0        138.0         500.0
# 5768   ZW  2008   9830.0         NaN          NaN        127.0         614.0
#
# ...

# %%
# Sposob na wyrzucenie wartosci "NaN"
df1 = df.dropna()

# %%
# Zrzut zbędnych zer, których było sporo
x = df1.copy()
for i in df:
    if i!="iso2":
        x=x[x[i]>0]
x
# Out:
#      iso2  year   new_sp  new_sp_m04  new_sp_m514  new_sp_m014  new_sp_m1524  \
# 244    AR  2008   4758.0        11.0         58.0         69.0         633.0
# 1620   ES  2005   2511.0         6.0          7.0         13.0         166.0
# 1621   ES  2006   2006.0        12.0          6.0         18.0         142.0
# 1622   ES  2007   2317.0         4.0          6.0         10.0         184.0
# 1822   GB  2007   1639.0         2.0         11.0         13.0         183.0
# 2478   IT  2006   1377.0         6.0          1.0          7.0         113.0
# 2480   IT  2008    938.0         1.0         12.0         13.0          78.0
# 4302   PT  2005   1302.0         3.0          2.0          5.0          85.0
# 4303   PT  2006   1300.0         4.0          3.0          7.0          80.0
# 4415   RO  2005  10801.0        10.0         26.0         36.0         752.0
#
#       new_sp_m2534  new_sp_m3544  new_sp_m4554  ...  new_sp_f04  new_sp_f514  \
# ...

# %%
# #zmiana nazw kolumn
# earthquake_data_renamed_columns = earthquake_data.rename(columns=
#                 {'In general, how worried are you about earthquakes?': "worried about earthquakes",
#                 'How worried are you about the Big One, a massive, catastrophic earthquake?': "worried about the Big One",
#                 'Do you think the "Big One" will occur in your lifetime?': "Big One during lifetime probability", 
#                 'Have you ever experienced an earthquake?': "experienced of earthquake",
#                 'Have you or anyone in your household taken any precautions for an earthquake (packed an earthquake survival kit, prepared an evacuation plan, etc.)?': "earthquake prevention",
#                 'How familiar are you with the San Andreas Fault line?': "knowledge about San Andreas Fault line",
#                 'How familiar are you with the Yellowstone Supervolcano?': "knowledge about Yellowstone Supervolcano",
#                 'Age': "age",
#                 'What is your gender?': "gender",
#                 'How much total combined money did all members of your HOUSEHOLD earn last year?': "household earnings",
#                 'US Region': "region"})
# earthquake_data_renamed_columns
